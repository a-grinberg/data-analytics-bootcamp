# %% [markdown]
# **Scenario:** You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.
#
# Tasks:
#
# **1. Data Preparation:**
#
# - Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# - Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# - Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# - Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
#
# **2. Data Analysis:**
#
# - Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# - Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# - Calculate the annual average temperature for each city.
#
# - Identify the city with the highest and lowest average temperature for the year.
#
# **3. Data Visualization:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = np.random.uniform(low=-5, high=35, size=(10, 12))
df = pd.DataFrame(data, columns=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
df.index = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5', 'City 6', 'City 7', 'City 8', 'City 9', 'City 10']
df.head()
# Out:
#           January   February      March      April        May       June  \
# City 1  12.331118  27.298539  14.127816  10.129853  -0.554882  29.950369
# City 2  31.946844  12.483811  25.259082   0.803057  -4.495195  12.056988
# City 3  13.549997  17.788564  20.992096   6.125603  25.884009   1.105536
# City 4  31.588380   8.937876  12.837121  27.135914  -4.581339   0.533298
# City 5  29.086950   3.396199  18.613002  31.799906  31.977408  24.567274
#
#              July     August  September    October   November   December
# City 1  19.214991   3.072860  28.378464  18.724957  16.516097  18.426776
# City 2  25.243173   8.392163  18.308046  31.138413   4.804862   4.936586
# City 3   8.783592  33.226653  25.445535  17.411109  -1.495823  16.195554
# City 4   7.138595  -2.176906   8.062730  13.896069  13.262645  25.058745
# City 5   7.500781  -3.901640  33.676691   4.334279  16.211880  -4.054817

# %%
df_mean = df.mean(axis=1)
df_mean
# Out:
# City 1     16.468080
# City 2     14.239819
# City 3     15.417702
# City 4     11.807761
# City 5     16.100659
# City 6     12.157418
# City 7     11.763367
# City 8     13.224363
# City 9      7.638580
# City 10    12.800681
# dtype: float64

# %%
print(f'The city with the highest average temperature is {df_mean.idxmax()} with an average temperature of {df_mean.max()} degrees Celsius.')
print(f'The city with the lowest average temperature is {df_mean.idxmin()} with an average temperature of {df_mean.min()} degrees Celsius.')
# Out:
# The city with the highest average temperature is City 1 with an average temperature of 16.468079728523193 degrees Celsius.
# The city with the lowest average temperature is City 9 with an average temperature of 7.63857991765083 degrees Celsius.

# %%
plt.figure(figsize=(14, 8))

for city in df.index:
    plt.plot(df.columns, df.loc[city], label=city)

plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.title('Monthly temperature data for each citi')
plt.xticks(rotation=45)
plt.legend(loc='best')
plt.grid(True)
plt.show()
