# %%
# !pip install kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-364e5597-43ab-41cd-a346-4785200f2d5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-364e5597-43ab-41cd-a346-4785200f2d5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                             title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# amanbarthwal/steam-store-data                                   Steam Store Data                                     6MB  2024-05-25 06:23:06            898         26  1.0
# khushikhushikhushi/imdb-top-rated-tv-series-dataset             IMDb Top-Rated TV Series Dataset                    73KB  2024-05-25 19:22:33            566         22  1.0
# kanchana1990/vehicle-dataset-2024                               Vehicle Dataset 2024                               308KB  2024-05-29 20:02:30            969         35  1.0
# ...

# %%
# !kaggle datasets download -d thedevastator/how-much-sleep-do-americans-really-get
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/how-much-sleep-do-americans-really-get
# License(s): copyright-authors
# ...
#   0% 0.00/7.62k [00:00<?, ?B/s]
# 100% 7.62k/7.62k [00:00<00:00, 11.5MB/s]

# %%
# !kaggle datasets download -d thedevastator/uncover-global-trends-in-mental-health-disorder
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/uncover-global-trends-in-mental-health-disorder
# License(s): other
# ...
#   0% 0.00/1.24M [00:00<?, ?B/s]
# 100% 1.24M/1.24M [00:00<00:00, 59.8MB/s]

# %%
# !kaggle datasets download -d samuelcortinhas/credit-card-approval-clean-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/samuelcortinhas/credit-card-approval-clean-data
# License(s): CC0-1.0
# ...
#   0% 0.00/19.0k [00:00<?, ?B/s]
# 100% 19.0k/19.0k [00:00<00:00, 27.6MB/s]

# %%
# !unzip how-much-sleep-do-americans-really-get.zip
# !unzip uncover-global-trends-in-mental-health-disorder.zip
# !unzip credit-card-approval-clean-data.zip
# Out:
# Archive:  how-much-sleep-do-americans-really-get.zip
#   inflating: Time Americans Spend Sleeping.csv
# Archive:  uncover-global-trends-in-mental-health-disorder.zip
#   inflating: Mental health Depression disorder Data.csv
# unzip:  cannot find or open credit-card-approval-clean-data.zip, credit-card-approval-clean-data.zip.zip or credit-card-approval-clean-data.zip.ZIP.

# %%
import pandas as pd
sleep_data = pd.read_csv('Time Americans Spend Sleeping.csv')
df_sleep = pd.DataFrame(sleep_data)
df_sleep.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# Quantitative Columns:
# Year,
# Sleeping,
# Standard Error
#
# Qualitative Columns:
# Sex,
# Period,
# Type of Days,
# Age group,
# Activity.
#
# Quantitative columns are numerical and can be measured. They represent quantities and can be subjected to mathematical operations such as sum, mean, median and so on.
# Qualitative variables describe qualities or characteristics and categorize data into groups or categories as well.

# %%
mental_data = pd.read_csv('Mental health Depression disorder Data.csv')
mental_df = pd.DataFrame(mental_data)
mental_df.head()
# Out:
# <ipython-input-21-ef8c7b4ab726>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental_data = pd.read_csv('Mental health Depression disorder Data.csv')
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# ...

# %% [markdown]
# Quantitative Columns:
# Year,
# Schizophrenia,
# Bipolar sisorder,
# Eating disorders,
# Anxiety disorders,
# Drug use disorders,
# Depression,
# Alcohol use disorders
#
# Qualitative Columns:
# Entity,
# Code,
#
#
# Quantitative columns are numerical and can be measured. They represent quantities and can be subjected to mathematical operations such as sum, mean, median and so on. \
# Qualitative variables describe qualities or characteristics and categorize data into groups or categories as well.

# %%
cards_data = pd.read_csv('clean_dataset.csv')
cards_df = pd.DataFrame(cards_data)
cards_df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# Quantitative Columns:
# Age, Debt, YearsEmployed, Credit score, Income
#
# Qualitative Columns:
# Gender, Married, BankCustomer, Industry, Ethnicity, PriorDefault, Employed, Driverse license, Citizen, ZipCode, Approved
#
#
# Quantitative columns are numerical and can be measured. They represent quantities and can be subjected to mathematical operations such as sum, mean, median and so on. \
# Qualitative variables describe qualities or characteristics and categorize data into groups or categories as well.
